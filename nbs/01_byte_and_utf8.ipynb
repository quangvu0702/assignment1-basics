# %% [markdown]
# ## BPE encoder

# %%
### Understanding Unicode
chr(0), chr(1), chr(2), chr(3)
# Out:
# ('\x00', '\x01', '\x02', '\x03')

# %%
ord("H")
# Out:
# 72

# %%
test_string = "Hello, con cò bé bé"

utf8_string = test_string.encode("utf-8")

print(utf8_string)

print(type(utf8_string))

list(utf8_string)
# Out:
# b'Hello, con c\xc3\xb2 b\xc3\xa9 b\xc3\xa9'
# <class 'bytes'>
# [72,
#  101,
#  108,
#  108,
#  111,
#  44,
#  32,
#  99,
#  111,
#  110,
#  32,
#  99,
#  195,
#  178,
#  32,
#  98,
#  195,
#  169,
#  32,
#  98,
#  195,
#  169]

# %%
print(len(utf8_string)), print(len(test_string))

print(utf8_string.decode("utf-8"))
# Out:
# 22
# 19
# Hello, con cò bé bé

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])
decode_utf8_bytes_to_str_wrong("hello c".encode("utf-8"))
# Out:
# 'hello c'

# %%
import regex as re

PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

re.findall(PAT, "Hello, con cò! bé bé")
# Out:
# ['Hello', ',', ' con', ' cò', '!', ' bé', ' bé']
