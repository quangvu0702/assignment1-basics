# %%
import heapq

max_heap = []
# push values (store negative)
heapq.heappush(max_heap, -10)
heapq.heappush(max_heap, -5)
heapq.heappush(max_heap, -20)

# pop max (remember to negate back)
# max_value = -heapq.heappop(max_heap)  # 20

# %%
heapq.heappop(max_heap)
# Out:
# -20

# %%
import heapq

pq = []
# push with negative priority
# heapq.heappush(pq, (-priority, item))

# example
heapq.heappush(pq, (-10, -3, {"key": "value"}))
heapq.heappush(pq, (-5, -100,  "taskB", 1))
heapq.heappush(pq, (-7, -2000,  "taskB", 2))
heapq.heappush(pq, (-3, -4,  "taskB", 3))
heapq.heappush(pq, (-10, -4, "taskA", 5))


pq
# priority, item = heapq.heappop(pq)
# priority = -priority  # restore positive priority
# Out:
# [(-10, -4, 'taskA', 5),
#  (-10, -3, {'key': 'value'}),
#  (-7, -2000, 'taskB', 2),
#  (-3, -4, 'taskB', 3),
#  (-5, -100, 'taskB', 1)]
